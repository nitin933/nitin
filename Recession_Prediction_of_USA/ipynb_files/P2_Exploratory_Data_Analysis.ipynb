# %% [markdown]
# ###Importing Requiered Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###Reading DataSet

# %%
df = pd.read_csv('Final DataFrame.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Year  Month  Inflation/CPI  UNRATE  FEDFUNDS    CCI  \
# 0           0  1982      1           94.4     8.6     13.22  97.50
# 1           1  1982      2           94.7     8.9     14.78  97.41
# 2           2  1982      3           94.7     9.0     14.68  97.27
# 3           3  1982      4           95.0     9.3     14.94  97.31
# 4           4  1982      5           95.9     9.4     14.45  97.38
#
#    Market_Cap_to_GDP  Avg T10Y3M  Housing Price  Debt_to_GDP  \
# 0           0.184275    1.676000         106.20     32.41298
# 1           0.184275    0.131500         106.20     32.41298
# 2           0.184275    0.546522         106.20     32.41298
# 3           0.182363    0.503182         108.84     32.40213
# 4           0.182363    0.865238         108.84     32.40213
#
#    Manufacturing Output    M2V  Recession_US
# 0             91.302757  1.842             1
# 1             91.302757  1.842             1
# 2             91.302757  1.842             1
# 3             91.302757  1.836             1
# 4             91.302757  1.836             1

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#    Year  Month  Inflation/CPI  UNRATE  FEDFUNDS    CCI  Market_Cap_to_GDP  \
# 0  1982      1           94.4     8.6     13.22  97.50           0.184275
# 1  1982      2           94.7     8.9     14.78  97.41           0.184275
# 2  1982      3           94.7     9.0     14.68  97.27           0.184275
# 3  1982      4           95.0     9.3     14.94  97.31           0.182363
# 4  1982      5           95.9     9.4     14.45  97.38           0.182363
#
#    Avg T10Y3M  Housing Price  Debt_to_GDP  Manufacturing Output    M2V  \
# 0    1.676000         106.20     32.41298             91.302757  1.842
# 1    0.131500         106.20     32.41298             91.302757  1.842
# 2    0.546522         106.20     32.41298             91.302757  1.842
# 3    0.503182         108.84     32.40213             91.302757  1.836
# 4    0.865238         108.84     32.40213             91.302757  1.836
#
#    Recession_US
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
df.tail()
# Out:
#      Year  Month  Inflation/CPI  UNRATE  FEDFUNDS    CCI  Market_Cap_to_GDP  \
# 480  2022      1        281.933     4.0      0.08  97.46           2.371155
# 481  2022      2        284.182     3.8      0.08  97.13           2.371155
# 482  2022      3        287.708     3.6      0.20  96.91           2.371155
# 483  2022      4        288.663     3.6      0.33  96.84           2.371155
# 484  2022      5        291.474     3.6      0.77  96.60           2.371155
#
#      Avg T10Y3M  Housing Price  Debt_to_GDP  Manufacturing Output    M2V  \
# 480    1.541429         578.58    122.87943               102.768  1.140
# 481    1.538500         578.58    122.87943               102.768  1.140
# 482    1.680435         578.58    122.87943               102.768  1.140
# 483    1.889524         617.89    121.07100               103.670  1.167
# 484    1.818636         617.89    121.07100               103.670  1.167
#
#      Recession_US
# 480             0
# 481             0
# 482             0
# 483             0
# 484             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  485 non-null    int64
#  1   Month                 485 non-null    int64
#  2   Inflation/CPI         485 non-null    float64
#  3   UNRATE                485 non-null    float64
#  4   FEDFUNDS              485 non-null    float64
#  5   CCI                   485 non-null    float64
#  6   Market_Cap_to_GDP     485 non-null    float64
#  7   Avg T10Y3M            485 non-null    float64
#  8   Housing Price         485 non-null    float64
#  9   Debt_to_GDP           485 non-null    float64
#  10  Manufacturing Output  485 non-null    float64
#  11  M2V                   485 non-null    float64
#  12  Recession_US          485 non-null    int64
# dtypes: float64(10), int64(3)
# memory usage: 49.4 KB

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Inflation/CPI', 'UNRATE', 'FEDFUNDS', 'CCI',
#        'Market_Cap_to_GDP', 'Avg T10Y3M', 'Housing Price', 'Debt_to_GDP',
#        'Manufacturing Output', 'M2V', 'Recession_US'],
#       dtype='object')

# %%
df.describe().drop(columns=['Year','Month','Recession_US'])
# Out:
#        Inflation/CPI      UNRATE    FEDFUNDS         CCI  Market_Cap_to_GDP  \
# count     485.000000  485.000000  485.000000  485.000000         485.000000
# mean      181.330862    6.140619    3.900124  100.109938           0.877226
# std        51.810688    1.790199    3.340533    1.488588           0.528545
# min        94.400000    3.500000    0.050000   96.440000           0.181416
# 25%       138.600000    4.800000    0.410000   99.090000           0.456154
# 50%       178.500000    5.700000    3.620000  100.570000           0.844218
# 75%       228.590000    7.200000    5.980000  101.080000           1.103970
# max       291.474000   14.700000   14.940000  102.990000           2.532661
#
#        Avg T10Y3M  Housing Price  Debt_to_GDP  Manufacturing Output  \
# count  485.000000     485.000000   485.000000            485.000000
# mean     1.662716     270.776577    71.168191             91.118162
# std      1.051640     112.473105    24.602312             12.565711
# min     -0.663333     106.200000    32.402130             62.798000
# 25%      0.821739     172.780000    55.484910             85.895000
# 50%      1.680435     262.800000    62.252970             95.541000
# 75%      2.515000     354.940000    97.827540            101.423000
# max      4.057727     617.890000   134.835280            108.149000
#
#               M2V
# count  485.000000
# mean     1.798614
# std      0.268266
# min      1.112000
# 25%      1.631000
# 50%      1.829000
# 75%      1.993000
# max      2.192000

# %% [markdown]
# ### Histograms for features

# %%
#Histogram for the Inflation/CPI Data
df['Inflation/CPI'].hist()
# Out:
# <Axes: >

# %%
#Histogram for the Unemployment Rate Data
df['UNRATE'].hist()
# Out:
# <Axes: >

# %%
#Histogram for the Effective Federal Funds Rate Data
df['FEDFUNDS'].hist()
# Out:
# <Axes: >

# %%
#Histogram for the Consumer Confidence Index Data
df['CCI'].hist()
# Out:
# <Axes: >

# %%
#Histogram for the Market Cap/GDP (Buffett Indicator) Data
df['Market_Cap_to_GDP'].hist()
# Out:
# <Axes: >

# %%
#Histogram for the Yield Curve Data
df['Avg T10Y3M'].hist()
# Out:
# <Axes: >

# %%
# Histogram for the M2 Velocity
df['M2V'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Boxplots for Features

# %%
df.boxplot(column=['Inflation/CPI'])
# Out:
# <Axes: >

# %%
df.boxplot(column = ['UNRATE'])
# Out:
# <Axes: >

# %%
df.boxplot(column = ['FEDFUNDS'])
# Out:
# <Axes: >

# %%
df.boxplot(column = ['CCI'])
# Out:
# <Axes: >

# %%
df.boxplot(column = ['Market_Cap_to_GDP'])
# Out:
# <Axes: >

# %%
df.boxplot(column = ['Avg T10Y3M'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['M2V'])
# Out:
# <Axes: >

# %% [markdown]
# ### Correlation Between Features

# %%
df[['Inflation/CPI', 'UNRATE', 'FEDFUNDS',
       'CCI', 'Market_Cap_to_GDP', 'Avg T10Y3M', 'Housing Price',
       'Debt_to_GDP', 'Manufacturing Output', 'M2V', 'Recession_US']].corr()
# Out:
#                       Inflation/CPI    UNRATE  FEDFUNDS       CCI  \
# Inflation/CPI              1.000000 -0.237280 -0.862150 -0.212979
# UNRATE                    -0.237280  1.000000  0.044088 -0.578681
# FEDFUNDS                  -0.862150  0.044088  1.000000  0.270903
# CCI                       -0.212979 -0.578681  0.270903  1.000000
# Market_Cap_to_GDP          0.887889 -0.384517 -0.664503  0.005079
# Avg T10Y3M                -0.146520  0.534637 -0.237928 -0.373346
# Housing Price              0.961051 -0.286409 -0.773377 -0.224949
# Debt_to_GDP                0.918863 -0.090145 -0.811555 -0.227259
# Manufacturing Output       0.681310 -0.176026 -0.485627 -0.006500
# M2V                       -0.601832 -0.142681  0.464613  0.322755
# Recession_US              -0.070915  0.152327  0.141666 -0.449370
#
#                       Market_Cap_to_GDP  Avg T10Y3M  Housing Price  \
# Inflation/CPI                  0.887889   -0.146520       0.961051
# UNRATE                        -0.384517    0.534637      -0.286409
# FEDFUNDS                      -0.664503   -0.237928      -0.773377
# CCI                            0.005079   -0.373346      -0.224949
# Market_Cap_to_GDP              1.000000   -0.315151       0.901188
# Avg T10Y3M                    -0.315151    1.000000      -0.207492
# Housing Price                  0.901188   -0.207492       1.000000
# Debt_to_GDP                    0.867876   -0.088878       0.848834
# Manufacturing Output           0.601269   -0.179438       0.683274
# M2V                           -0.644412   -0.042872      -0.622106
# Recession_US                  -0.141309    0.032399      -0.042684
#
#                       Debt_to_GDP  Manufacturing Output       M2V  \
# Inflation/CPI            0.918863              0.681310 -0.601832
# UNRATE                  -0.090145             -0.176026 -0.142681
# FEDFUNDS                -0.811555             -0.485627  0.464613
# CCI                     -0.227259             -0.006500  0.322755
# Market_Cap_to_GDP        0.867876              0.601269 -0.644412
# Avg T10Y3M              -0.088878             -0.179438 -0.042872
# Housing Price            0.848834              0.683274 -0.622106
# Debt_to_GDP              1.000000              0.463569 -0.755154
# Manufacturing Output     0.463569              1.000000 -0.298510
# M2V                     -0.755154             -0.298510  1.000000
# Recession_US            -0.157862             -0.021902  0.054042
#
#                       Recession_US
# Inflation/CPI            -0.070915
# UNRATE                    0.152327
# FEDFUNDS                  0.141666
# CCI                      -0.449370
# Market_Cap_to_GDP        -0.141309
# Avg T10Y3M                0.032399
# Housing Price            -0.042684
# Debt_to_GDP              -0.157862
# Manufacturing Output     -0.021902
# M2V                       0.054042
# Recession_US              1.000000

# %%
# Create a colormap for the heatmap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Create a correlation heatmap
sns.heatmap(df[['Inflation/CPI', 'UNRATE', 'FEDFUNDS',
       'CCI', 'Market_Cap_to_GDP', 'Avg T10Y3M', 'Housing Price',
       'Debt_to_GDP', 'Manufacturing Output', 'M2V', 'Recession_US']].corr(),vmax=1, center=0, cmap=cmap,
            square=True, linewidths=.3, cbar_kws={"shrink": 1})
# Out:
# <Axes: >
